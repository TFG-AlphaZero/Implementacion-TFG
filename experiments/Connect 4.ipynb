# %%
import os


if 'tfg' not in os.listdir():
    os.chdir('..')

# %%
from tfg.alphaZero import create_alphazero
from tfg.alphaZeroCallbacks import Checkpoint
from tfg.alphaZeroAdapters import ConnectNAdapter
from tfg.util import enable_gpu
from tfg.alphaZeroConfig import AlphaZeroConfig
from game.connect_n import ConnectN

import time

# %%
enable_gpu()

game = ConnectN()

# %%
# This training ended with an error after 1320 games and about 14 hours
config = AlphaZeroConfig(
    learning_rate=.01,
    regularizer_constant=.0001,
    momentum=.0,
    residual_layers=12,
    filters=128,
    kernel_size=(3, 3)
)

checkpoint = Checkpoint(directory='models/checkpoints/connect4', delay=2)

start = time.time()

alphazero = create_alphazero(game, ConnectNAdapter(game), max_workers=12,
                             self_play_times=120, max_games_counter=2400,
                             buffer_size=6000, batch_size=512, temperature=20,
                             callbacks=[checkpoint], epochs=20,
                             c_puct=1, exploration_noise=(.25, .06),
                             mcts_iter=600, nn_config=config)

print("Finished training after", time.time() - start, "seconds")
# Out:
# 2021-04-17 16:37:44,259	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# Epoch 1/20
# 16/16 - 11s - loss: 2.2722 - value_head_loss: 1.0149 - policy_head_loss: 2.0436
# Epoch 2/20
# 16/16 - 0s - loss: 2.7268 - value_head_loss: 0.9419 - policy_head_loss: 1.9621
# Epoch 3/20
# 16/16 - 0s - loss: 2.7780 - value_head_loss: 0.9520 - policy_head_loss: 1.9541
# Epoch 4/20
# 16/16 - 0s - loss: 2.6645 - value_head_loss: 0.9309 - policy_head_loss: 1.9340
# Epoch 5/20
# 16/16 - 0s - loss: 2.5282 - value_head_loss: 0.8986 - policy_head_loss: 1.9288
# Epoch 6/20
# 16/16 - 0s - loss: 2.4320 - value_head_loss: 0.9268 - policy_head_loss: 1.9288
# Epoch 7/20
# 16/16 - 0s - loss: 2.3231 - value_head_loss: 0.9100 - policy_head_loss: 1.9213
# Epoch 8/20
# 16/16 - 0s - loss: 2.1846 - value_head_loss: 0.8252 - policy_head_loss: 1.9041
# Epoch 9/20
# 16/16 - 0s - loss: 2.1141 - value_head_loss: 0.8320 - policy_head_loss: 1.9156
# Epoch 10/20
# ...

# %%
# We will try it again starting from last checkpoint (1200 games)
config = AlphaZeroConfig(
    learning_rate=.01,
    regularizer_constant=.0001,
    momentum=.0,
    residual_layers=12,
    filters=128,
    kernel_size=(3, 3)
)

checkpoint = Checkpoint(prefix='checkpoint5+',
                        directory='models/checkpoints/connect4',
                        delay=2)

start = time.time()

alphazero = create_alphazero(game, ConnectNAdapter(game), max_workers=12,
                             initial_weights='models/checkpoints/connect4/checkpoint5.h5',
                             self_play_times=120, max_games_counter=1200,
                             buffer_size=6000, batch_size=512, temperature=20,
                             callbacks=[checkpoint], epochs=20,
                             c_puct=1, exploration_noise=(.25, .06),
                             mcts_iter=600, nn_config=config)

print("Finished training after", time.time() - start, "seconds")
# Out:
# 2021-04-22 17:45:26,923	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# Epoch 1/20
# 16/16 - 7s - loss: 1.6289 - value_head_loss: 1.0504 - policy_head_loss: 1.7834
# Epoch 2/20
# 16/16 - 0s - loss: 1.3427 - value_head_loss: 0.6986 - policy_head_loss: 1.4996
# Epoch 3/20
# 16/16 - 0s - loss: 1.1630 - value_head_loss: 0.5101 - policy_head_loss: 1.3343
# Epoch 4/20
# 16/16 - 0s - loss: 1.0566 - value_head_loss: 0.4516 - policy_head_loss: 1.1905
# Epoch 5/20
# 16/16 - 0s - loss: 0.9747 - value_head_loss: 0.3719 - policy_head_loss: 1.1286
# Epoch 6/20
# 16/16 - 0s - loss: 0.9523 - value_head_loss: 0.3689 - policy_head_loss: 1.0856
# Epoch 7/20
# 16/16 - 0s - loss: 0.8894 - value_head_loss: 0.2998 - policy_head_loss: 1.0368
# Epoch 8/20
# 16/16 - 0s - loss: 0.8613 - value_head_loss: 0.3059 - policy_head_loss: 0.9932
# Epoch 9/20
# 16/16 - 0s - loss: 0.8758 - value_head_loss: 0.3588 - policy_head_loss: 0.9786
# Epoch 10/20
# ...

# %%
# We will try it again starting from last checkpoint (3600 games)
config = AlphaZeroConfig(
    learning_rate=.01,
    regularizer_constant=.0001,
    momentum=.0,
    residual_layers=12,
    filters=128,
    kernel_size=(3, 3)
)

checkpoint = Checkpoint(prefix='checkpoint15+',
                        directory='models/checkpoints/connect4',
                        delay=4)

start = time.time()

alphazero = create_alphazero(game, ConnectNAdapter(game), max_workers=12,
                             initial_weights='models/checkpoints/connect4/checkpoint10+5.h5',
                             self_play_times=60, max_games_counter=960,
                             buffer_size=3000, batch_size=1024, temperature=20,
                             callbacks=[checkpoint], epochs=20,
                             c_puct=1, exploration_noise=(.25, .06),
                             mcts_iter=600, nn_config=config)

print("Finished training after", time.time() - start, "seconds")
# Out:
# 2021-04-26 00:58:50,160	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# Epoch 1/20
# 32/32 - 10s - loss: 1.1503 - value_head_loss: 0.5331 - policy_head_loss: 1.4114
# Epoch 2/20
# 32/32 - 0s - loss: 0.8831 - value_head_loss: 0.3627 - policy_head_loss: 1.0218
# Epoch 3/20
# 32/32 - 1s - loss: 0.7524 - value_head_loss: 0.3006 - policy_head_loss: 0.8471
# Epoch 4/20
# 32/32 - 1s - loss: 0.6818 - value_head_loss: 0.2798 - policy_head_loss: 0.7472
# Epoch 5/20
# 32/32 - 1s - loss: 0.6234 - value_head_loss: 0.2559 - policy_head_loss: 0.6674
# Epoch 6/20
# 32/32 - 1s - loss: 0.6396 - value_head_loss: 0.2575 - policy_head_loss: 0.6820
# Epoch 7/20
# 32/32 - 1s - loss: 0.6114 - value_head_loss: 0.2444 - policy_head_loss: 0.6327
# Epoch 8/20
# 32/32 - 1s - loss: 0.5737 - value_head_loss: 0.2341 - policy_head_loss: 0.5734
# Epoch 9/20
# 32/32 - 0s - loss: 0.5565 - value_head_loss: 0.2224 - policy_head_loss: 0.5471
# Epoch 10/20
# ...

# %%
# We will try it again starting from last checkpoint (4560 games)
config = AlphaZeroConfig(
    learning_rate=.01,
    regularizer_constant=.0001,
    momentum=.0,
    residual_layers=12,
    filters=128,
    kernel_size=(3, 3)
)

checkpoint = Checkpoint(prefix='checkpoint19+',
                        directory='models/checkpoints/connect4',
                        delay=4)

start = time.time()

alphazero = create_alphazero(game, ConnectNAdapter(game), max_workers=12,
                             initial_weights='models/checkpoints/connect4/checkpoint15+4.h5',
                             self_play_times=60, max_games_counter=1440,
                             buffer_size=3000, batch_size=1024, temperature=20,
                             callbacks=[checkpoint], epochs=20,
                             c_puct=1, exploration_noise=(.25, .06),
                             mcts_iter=600, nn_config=config)

print("Finished training after", time.time() - start, "seconds")
# Out:
# 2021-04-27 01:04:14,873	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# Epoch 1/20
# 32/32 - 8s - loss: 1.3644 - value_head_loss: 0.7935 - policy_head_loss: 1.5670
# Epoch 2/20
# 32/32 - 0s - loss: 1.0177 - value_head_loss: 0.4877 - policy_head_loss: 1.1505
# Epoch 3/20
# 32/32 - 0s - loss: 0.8744 - value_head_loss: 0.3814 - policy_head_loss: 0.9872
# Epoch 4/20
# 32/32 - 0s - loss: 0.8141 - value_head_loss: 0.3513 - policy_head_loss: 0.9028
# Epoch 5/20
# 32/32 - 0s - loss: 0.7504 - value_head_loss: 0.3248 - policy_head_loss: 0.8038
# Epoch 6/20
# 32/32 - 0s - loss: 0.6968 - value_head_loss: 0.2774 - policy_head_loss: 0.7515
# Epoch 7/20
# 32/32 - 0s - loss: 0.6762 - value_head_loss: 0.2740 - policy_head_loss: 0.7165
# Epoch 8/20
# 32/32 - 0s - loss: 0.6494 - value_head_loss: 0.2478 - policy_head_loss: 0.6905
# Epoch 9/20
# 32/32 - 0s - loss: 0.6146 - value_head_loss: 0.2446 - policy_head_loss: 0.6304
# Epoch 10/20
# ...

# %%
# We will try it again starting from last checkpoint (6000 games)
config = AlphaZeroConfig(
    learning_rate=.01,
    regularizer_constant=.0001,
    momentum=.0,
    residual_layers=12,
    filters=128,
    kernel_size=(3, 3)
)

checkpoint = Checkpoint(prefix='checkpoint25+',
                        directory='models/checkpoints/connect4',
                        delay=4)

start = time.time()

alphazero = create_alphazero(game, ConnectNAdapter(game), max_workers=12,
                             initial_weights='models/checkpoints/connect4/checkpoint19+6.h5',
                             self_play_times=60, max_games_counter=1920,
                             buffer_size=3000, batch_size=1024, temperature=20,
                             callbacks=[checkpoint], epochs=10,
                             c_puct=1, exploration_noise=(.25, .06),
                             mcts_iter=600, nn_config=config)

print("Finished training after", time.time() - start, "seconds")
# Out:
# 2021-04-29 01:10:16,740	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# Epoch 1/10
# 32/32 - 8s - loss: 1.1923 - value_head_loss: 0.5528 - policy_head_loss: 1.5326
# Epoch 2/10
# 32/32 - 0s - loss: 0.8798 - value_head_loss: 0.3285 - policy_head_loss: 1.1075
# Epoch 3/10
# 32/32 - 0s - loss: 0.7458 - value_head_loss: 0.2521 - policy_head_loss: 0.9261
# Epoch 4/10
# 32/32 - 0s - loss: 0.6578 - value_head_loss: 0.2220 - policy_head_loss: 0.8010
# Epoch 5/10
# 32/32 - 0s - loss: 0.6074 - value_head_loss: 0.2029 - policy_head_loss: 0.7216
# Epoch 6/10
# 32/32 - 0s - loss: 0.5790 - value_head_loss: 0.1993 - policy_head_loss: 0.6641
# Epoch 7/10
# 32/32 - 0s - loss: 0.5897 - value_head_loss: 0.2010 - policy_head_loss: 0.6785
# Epoch 8/10
# 32/32 - 0s - loss: 0.5742 - value_head_loss: 0.1911 - policy_head_loss: 0.6480
# Epoch 9/10
# 32/32 - 0s - loss: 0.5509 - value_head_loss: 0.1940 - policy_head_loss: 0.5981
# Epoch 10/10
# ...

# %%
# We will try it again starting from last checkpoint (7920 games)
config = AlphaZeroConfig(
    learning_rate=.01,
    regularizer_constant=.0001,
    momentum=.0,
    residual_layers=12,
    filters=128,
    kernel_size=(3, 3)
)

checkpoint = Checkpoint(prefix='checkpoint33+',
                        directory='models/checkpoints/connect4',
                        delay=4)

start = time.time()

alphazero = create_alphazero(game, ConnectNAdapter(game), max_workers=12,
                             initial_weights='models/checkpoints/connect4/checkpoint25+8.h5',
                             self_play_times=60, max_games_counter=2400,
                             buffer_size=3000, batch_size=1024, temperature=20,
                             callbacks=[checkpoint], epochs=10,
                             c_puct=1, exploration_noise=(.25, .06),
                             mcts_iter=600, nn_config=config)

print("Finished training after", time.time() - start, "seconds")
# Out:
# 2021-04-29 18:23:57,366	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# Epoch 1/10
# 32/32 - 8s - loss: 1.0846 - value_head_loss: 0.4590 - policy_head_loss: 1.3972
# Epoch 2/10
# 32/32 - 0s - loss: 0.8189 - value_head_loss: 0.2870 - policy_head_loss: 1.0306
# Epoch 3/10
# 32/32 - 0s - loss: 0.7074 - value_head_loss: 0.2191 - policy_head_loss: 0.8723
# Epoch 4/10
# 32/32 - 0s - loss: 0.6419 - value_head_loss: 0.1989 - policy_head_loss: 0.7707
# Epoch 5/10
# 32/32 - 0s - loss: 0.6167 - value_head_loss: 0.1935 - policy_head_loss: 0.7162
# Epoch 6/10
# 32/32 - 0s - loss: 0.5729 - value_head_loss: 0.1699 - policy_head_loss: 0.6545
# Epoch 7/10
# 32/32 - 0s - loss: 0.5403 - value_head_loss: 0.1610 - policy_head_loss: 0.6113
# Epoch 8/10
# 32/32 - 0s - loss: 0.5229 - value_head_loss: 0.1513 - policy_head_loss: 0.5875
# Epoch 9/10
# 32/32 - 0s - loss: 0.5003 - value_head_loss: 0.1486 - policy_head_loss: 0.5517
# Epoch 10/10
# ...

# %%
alphazero.save('models/Connect4.h5')

# %%
# %%javascript
# IPython.notebook.save_notebook()
